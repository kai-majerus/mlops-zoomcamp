# %% [markdown]
# ## Scenario 1: A single data scientist participating in an ML competition
#
# MLflow setup:
# * Tracking server: no
# * Backend store: local filesystem
# * Artifacts store: local filesystem
#
# The experiments can be explored locally by launching the MLflow UI.

# %%
import mlflow

# %%
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")
# Out:
# tracking URI: 'sqlite:////workspaces/mlops-zoomcamp/02-experiment-tracking/running_mlflow_examples/mlflow.db'

# %%
# This code creates mlflow.db file locally
mlflow.search_experiments()
# Out:
# 2026/04/21 06:24:53 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/04/21 06:24:53 INFO mlflow.store.db.utils: Updating database tables
# [<Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/running_mlflow_examples/mlruns/0', creation_time=1776752694488, experiment_id='0', last_update_time=1776752694488, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %%
## Kill all localhosts 5000
# kill -9 $(lsof -ti :5000)

# %%
# mlflow ui --backend-store-uri sqlite:////workspaces/mlops-zoomcamp/02-experiment-tracking/running_mlflow_examples/mlflow.db

# %% [markdown]
# ### Creating an experiment and logging a new run

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# This code creates mlruns folder locally

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, name="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2026/04/21 06:31:39 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2026/04/21 06:31:39 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/04/21 06:31:39 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# default artifacts URI: '/workspaces/mlops-zoomcamp/02-experiment-tracking/running_mlflow_examples/mlruns/1/86c538eb4fd64692bb6bca481409a70a/artifacts'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/running_mlflow_examples/mlruns/1', creation_time=1776753099147, experiment_id='1', last_update_time=1776753099147, lifecycle_stage='active', name='my-experiment-1', tags={}, trace_location=None, workspace='default'>,
#  <Experiment: artifact_location='/workspaces/mlops-zoomcamp/02-experiment-tracking/running_mlflow_examples/mlruns/0', creation_time=1776752694488, experiment_id='0', last_update_time=1776752694488, lifecycle_stage='active', name='Default', tags={}, trace_location=None, workspace='default'>]

# %% [markdown]
# ### Interacting with the model registry

# %%
from mlflow.tracking import MlflowClient


client = MlflowClient()

# %%
from mlflow.exceptions import MlflowException

# Seems that mlflow now creates mlflow.db by default, so we can always access the model registry

try:
    client.search_registered_models()
except MlflowException:
    print("It's not possible to access the model registry :(")
